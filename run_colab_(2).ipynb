# %% [markdown]
# <a href="https://colab.research.google.com/github/Athiyah17/portofolio.github.io/blob/main/run_colab_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ── 1. Install dependencies ────────────────────────────────────────
# !pip install -q streamlit timm torchvision matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 100.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 101.0 MB/s eta 0:00:00

# %%
# ── 2. Cek file sudah ada ──────────────────────────────────────────
import os

assert os.path.exists('app.py'), '❌ app.py tidak ditemukan! Upload dulu via panel Files.'
assert os.path.exists('best_model.pkl'), '❌ /best_model.pkl tidak ditemukan!'

print('✅ app.py ditemukan')
print('✅ output/best_model.pkl ditemukan')
print('🚀 Siap dijalankan!')
# Out:
# ✅ app.py ditemukan
# ✅ output/best_model.pkl ditemukan
# 🚀 Siap dijalankan!

# %%
# ── 3. Ambil IP publik (dipakai sebagai tunnel password nanti) ─────
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.21.148.126

# %%
# ── 4. Jalankan Streamlit + localtunnel ───────────────────────────
# Setelah link muncul, klik → paste IP dari sel di atas sebagai tunnel password
# !streamlit run app.py &>/dev/null & npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹your url is: https://beige-grapes-travel.loca.lt

# %%
# ── 5. (Opsional) Stop server ──────────────────────────────────────
# !pkill -f streamlit
print('🛑 Server dihentikan.')
